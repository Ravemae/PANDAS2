# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
air_quality = pd.read_csv('Air_quality_no2.csv')
air_quality
# Out:
#                  datetime  station_antwerp  station_paris  station_london
# 0     2019-05-07 02:00:00              NaN            NaN            23.0
# 1     2019-05-07 03:00:00             50.5           25.0            19.0
# 2     2019-05-07 04:00:00             45.0           27.7            19.0
# 3     2019-05-07 05:00:00              NaN           50.4            16.0
# 4     2019-05-07 06:00:00              NaN           61.9             NaN
# ...                   ...              ...            ...             ...
# 1030  2019-06-20 22:00:00              NaN           21.4             NaN
# 1031  2019-06-20 23:00:00              NaN           24.9             NaN
# 1032  2019-06-21 00:00:00              NaN           26.5             NaN
# 1033  2019-06-21 01:00:00              NaN           21.8             NaN
# 1034  2019-06-21 02:00:00              NaN           20.0             NaN
#
# [1035 rows x 4 columns]

# %%
air_quality.plot()
# Out:
# <Axes: >

# %%
air_quality["station_paris"].plot()
plt.show()

# %%
air_quality.plot.scatter(x="station_london", y="station_paris", alpha=0.5)
plt.show()

# %%
air_quality.plot.scatter(x="station_paris", y="station_antwerp", alpha=0.5)
plt.show()

# %%
air_quality["london_mg_per_cubic"] = air_quality["station_london"] * 1.882
air_quality
# Out:
#                  datetime  station_antwerp  station_paris  station_london  \
# 0     2019-05-07 02:00:00              NaN            NaN            23.0
# 1     2019-05-07 03:00:00             50.5           25.0            19.0
# 2     2019-05-07 04:00:00             45.0           27.7            19.0
# 3     2019-05-07 05:00:00              NaN           50.4            16.0
# 4     2019-05-07 06:00:00              NaN           61.9             NaN
# ...                   ...              ...            ...             ...
# 1030  2019-06-20 22:00:00              NaN           21.4             NaN
# 1031  2019-06-20 23:00:00              NaN           24.9             NaN
# 1032  2019-06-21 00:00:00              NaN           26.5             NaN
# 1033  2019-06-21 01:00:00              NaN           21.8             NaN
# 1034  2019-06-21 02:00:00              NaN           20.0             NaN
#
#       london_mg_per_cubic
# 0                  43.286
# ...

# %%
air_quality["ratio_paris_antwerp"] = (
    air_quality["station_paris"] / air_quality["station_antwerp"]
)
air_quality.head()
# Out:
#               datetime  station_antwerp  station_paris  station_london  \
# 0  2019-05-07 02:00:00              NaN            NaN            23.0
# 1  2019-05-07 03:00:00             50.5           25.0            19.0
# 2  2019-05-07 04:00:00             45.0           27.7            19.0
# 3  2019-05-07 05:00:00              NaN           50.4            16.0
# 4  2019-05-07 06:00:00              NaN           61.9             NaN
#
#    london_mg_per_cubic  ratio_paris_antwerp
# 0               43.286                  NaN
# 1               35.758             0.495050
# 2               35.758             0.615556
# 3               30.112                  NaN
# 4                  NaN                  NaN

# %%
air_quality["ratio_paris_antwerp(%)"] = (
    (air_quality["station_paris"] / air_quality["station_antwerp"]) * 100
)
air_quality.head()
# Out:
#               datetime  station_antwerp  station_paris  station_london  \
# 0  2019-05-07 02:00:00              NaN            NaN            23.0
# 1  2019-05-07 03:00:00             50.5           25.0            19.0
# 2  2019-05-07 04:00:00             45.0           27.7            19.0
# 3  2019-05-07 05:00:00              NaN           50.4            16.0
# 4  2019-05-07 06:00:00              NaN           61.9             NaN
#
#    london_mg_per_cubic  ratio_paris_antwerp  ratio_paris_antwerp(%)
# 0               43.286                  NaN                     NaN
# 1               35.758             0.495050               49.504950
# 2               35.758             0.615556               61.555556
# 3               30.112                  NaN                     NaN
# 4                  NaN                  NaN                     NaN

# %%
air_quality_renamed = air_quality.rename(
    columns={
        "station_antwerp": "Ant_nation",
        "station_paris": "Paris_station",
        "station_london": "estacion_española"
    }
)
air_quality_renamed.head()
# Out:
#               datetime  Ant_nation  Paris_station  estacion_española  \
# 0  2019-05-07 02:00:00         NaN            NaN               23.0
# 1  2019-05-07 03:00:00        50.5           25.0               19.0
# 2  2019-05-07 04:00:00        45.0           27.7               19.0
# 3  2019-05-07 05:00:00         NaN           50.4               16.0
# 4  2019-05-07 06:00:00         NaN           61.9                NaN
#
#    london_mg_per_cubic  ratio_paris_antwerp  ratio_paris_antwerp(%)
# 0               43.286                  NaN                     NaN
# 1               35.758             0.495050               49.504950
# 2               35.758             0.615556               61.555556
# 3               30.112                  NaN                     NaN
# 4                  NaN                  NaN                     NaN
