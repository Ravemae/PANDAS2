# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 import re
#       3 import matplotlib.pyplot as plt
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\__init__.py:62
#      59 # let init-time option registration happen
#      60 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 62 from pandas.core.api import (
#      63     # dtype
#      64     ArrowDtype,
#      65     Int8Dtype,
#      66     Int16Dtype,
#      67     Int32Dtype,
#      68     Int64Dtype,
#      69     UInt8Dtype,
#      70     UInt16Dtype,
#      71     UInt32Dtype,
#      72     UInt64Dtype,
#      73     Float32Dtype,
#      74     Float64Dtype,
#      75     CategoricalDtype,
#      76     PeriodDtype,
#      77     IntervalDtype,
#      78     DatetimeTZDtype,
# ...

# %%
data = pd.read_csv("Covid_Data.csv")
data
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1    1             1  03/05/2020       97
# 1            2             1    2             1  03/06/2020       97
# 2            2             1    2             2  09/06/2020        1
# 3            2             1    1             1  12/06/2020       97
# 4            2             1    2             1  21/06/2020       97
# ...        ...           ...  ...           ...         ...      ...
# 1048570      2            13    2             1  9999-99-99       97
# 1048571      1            13    2             2  9999-99-99        2
# 1048572      2            13    2             1  9999-99-99       97
# 1048573      2            13    2             1  9999-99-99       97
# 1048574      2            13    2             1  9999-99-99       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  \
# 0                1   65         2         2  ...       2        2
# ...

# %%
xl = data.to_excel("c_19.xlsx", sheet_name="Victims", index=False)
xl = pd.read_excel("c_19.xlsx")
xl
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1    1             1  03/05/2020       97
# 1            2             1    2             1  03/06/2020       97
# 2            2             1    2             2  09/06/2020        1
# 3            2             1    1             1  12/06/2020       97
# 4            2             1    2             1  21/06/2020       97
# ...        ...           ...  ...           ...         ...      ...
# 1048570      2            13    2             1  9999-99-99       97
# 1048571      1            13    2             2  9999-99-99        2
# 1048572      2            13    2             1  9999-99-99       97
# 1048573      2            13    2             1  9999-99-99       97
# 1048574      2            13    2             1  9999-99-99       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  \
# 0                1   65         2         2  ...       2        2
# ...

# %%
data.plot.bar(x='sex', y='AGE')

# %%
data['SEX'] = data['SEX'].replace({1: 'Female', 2: 'Male'})
data
# Out:
#          USMER  MEDICAL_UNIT     SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1  Female             1  03/05/2020       97
# 1            2             1    Male             1  03/06/2020       97
# 2            2             1    Male             2  09/06/2020        1
# 3            2             1  Female             1  12/06/2020       97
# 4            2             1    Male             1  21/06/2020       97
# ...        ...           ...     ...           ...         ...      ...
# 1048570      2            13    Male             1  9999-99-99       97
# 1048571      1            13    Male             2  9999-99-99        2
# 1048572      2            13    Male             1  9999-99-99       97
# 1048573      2            13    Male             1  9999-99-99       97
# 1048574      2            13    Male             1  9999-99-99       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  \
# ...

# %%
data['USMER'].plot.bar()
plt.show()

# %%
data['USMER'].plot.scatter()
plt.show()

# %%
data['MEDICAL_UNIT'].plot.bar()
plt.show()

# %%
data['PATIENT_TYPE'].plot.bar()
plt.show()

# %%
data.plot.bar(x='PREGNANT', y='AGE')

# %%
data.plot.bar(x='DIABETES', y='AGE')

# %%
data.plot.bar(x='PNEUMONIA', y='AGE')

# %%
data.plot.bar(x='ASTHMA', y='AGE')

# %%
data.plot.bar(x='INMSUPR', y='AGE')

# %%
data.plot.bar(x='HIPERTENSION ', y='AGE')

# %%
data.plot.bar(x='OTHER_DISEASE', y='AGE')

# %%
data.plot.bar(x='CARDIOVASCULAR', y='AGE')

# %%
data.plot.bar(x='OBESITY', y='AGE')

# %%
data.plot.bar(x='RENAL_CHRONIC', y='AGE')

# %%
data.plot.bar(x='TOBACCO', y='AGE')

# %%
data.plot.bar(x='CLASIFFICATION_FINAL', y='AGE')

# %%
data.plot.bar(x='ICU', y='AGE')

# %%
data.plot.pie(x='DATE_DIED', y='AGE')

# %%
data.plot.bar(x='DATE_DIED', y='PREGNANT')
